# %%
import pandas as pd
import numpy as np
import random

# %%
import os
print(os.getcwd())
# Out:
# f:\collage\NLP\Assignment_5

# %%
with open(r"F:/collage/NLP/Assignment_1/2/gu_meta_part_4_sentences.txt", "r", encoding="utf-8") as f:
    sentences = [line.strip() for line in f if line.strip()]  

# Wrap in DataFrame for convenience
df = pd.DataFrame(sentences, columns=["sentence"])

# Show 10 random sentences
print(df.sample(10),"\n\n")
print("Total sentences:", len(df))
# Out:
#                                                   sentence
# 265142   આ સંદર્ભે આપે ફકત આપના બ્લોગ ઉપર યથાયોગ્ય સ્થા...
# 657130   આભાર ! n સ - સ્નેહ n અરવિંદ nLikeLiked by 1 pe...
# 1355236  I DEFINATELY LIKED YOUR EAGERNESS TO KNOW THE ...
# 897426   ઓરડામાં આ સર્વ બાબતો પરથી ‘ આપણે તેમનો આદર કરવ...
# 1169053                                      નવો અવતાર ! !
# 990118   Majmudar Gold Medal ” to the Under Graduate St...
# 462738   નવસારીની ખાસ સભા અસામાન્ય સભા મોકુફ રાખવા બાબત...
# 272590    પરીક્ષા અને ઇન્ટરવ્યુ વગેરેમાં તમને સફળતા મળશે .
# 645949   બાદમાં ગંભીર રીતે ઘવાયેલા સાજણને તુરંત જ સારવા...
# 642687                          i like your blog so much .
#
#
# Total sentences: 1600544

# %%
np.random.seed(42)

indices=np.random.permutation(len(df))

val_idx =indices[:1000]
test_idx=indices[1000:2000]
train_idx =indices[2000:]

val=df.iloc[val_idx]
test=df.iloc[test_idx]
train=df.iloc[train_idx]

print(len(train))
print(len(val))
print(len(test))
# Out:
# 1598544
# 1000
# 1000

# %%
train.to_csv("train_sentences.csv", index=False, encoding="utf-8")
val.to_csv("val_sentences.csv", index=False, encoding="utf-8")
test.to_csv("test_sentences.csv", index=False, encoding="utf-8")

print("Data splits saved successfully.")
# Out:
# Data splits saved successfully.
